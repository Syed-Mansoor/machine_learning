# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[165.0,137.0,472.0,192.0],[101.0,92.0,250.0,144.0],[29.0,127.0,201.0,91.0]],columns = ['R&D','Ops','Marketing','Profit'])

# %%
df
# Out:
#      R&D    Ops  Marketing  Profit
# 0  165.0  137.0      472.0   192.0
# 1  101.0   92.0      250.0   144.0
# 2   29.0  127.0      201.0    91.0

# %%
df['f0(x)']=df['Profit'].mean()
df
# Out:
#      R&D    Ops  Marketing  Profit       f0(x)
# 0  165.0  137.0      472.0   192.0  142.333333
# 1  101.0   92.0      250.0   144.0  142.333333
# 2   29.0  127.0      201.0    91.0  142.333333

# %%
df['r1'] = df['Profit'] - df['f0(x)']

# %%
df
# Out:
#      R&D    Ops  Marketing  Profit       f0(x)         r1
# 0  165.0  137.0      472.0   192.0  142.333333  49.666667
# 1  101.0   92.0      250.0   144.0  142.333333   1.666667
# 2   29.0  127.0      201.0    91.0  142.333333 -51.333333

# %%
from sklearn.tree import DecisionTreeRegressor
reg =DecisionTreeRegressor(max_depth=3)
reg.fit(df.iloc[:,0:3].values,df.iloc[:,-1])
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
from sklearn.tree import plot_tree
plot_tree(reg,filled = True,rounded = True)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[0] <= 65.0\nsquared_error = 1701.556\nsamples = 3\nvalue = -0.0'),
#  Text(0.2, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = -51.333'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[1] <= 114.5\nsquared_error = 576.0\nsamples = 2\nvalue = 25.667'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 1.667'),
#  Text(0.8, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 49.667')]
