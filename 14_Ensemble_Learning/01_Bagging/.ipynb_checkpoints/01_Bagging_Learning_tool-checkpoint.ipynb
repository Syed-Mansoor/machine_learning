# %%
import pandas as pd
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

df['species'] = encoder.fit_transform(df['species'])

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
df = df[df['species'] != 0 ][['sepal_width','petal_length','species']]

# %%
df.head()
# Out:
#     sepal_width  petal_length  species
# 50          3.2           4.7        1
# 51          3.2           4.5        1
# 52          3.1           4.9        1
# 53          2.3           4.0        1
# 54          2.8           4.6        1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['sepal_width'],df['petal_length'],c = df['species'],cmap = 'winter')
plt.show()

# %%
# Taking only 10 rows for training
df = df.sample(100)
df_train = df.iloc[:60,:].sample(10)
df_val = df.iloc[60:80,:].sample(5)
df_test = df.iloc[80:,:].sample(5)

# %%
df_train
# Out:
#      sepal_width  petal_length  species
# 60           2.0           3.5        1
# 92           2.6           4.0        1
# 149          3.0           5.1        2
# 140          3.1           5.6        2
# 124          3.3           5.7        2
# 135          3.0           6.1        2
# 66           3.0           4.5        1
# 108          2.5           5.8        2
# 99           2.8           4.1        1
# 97           2.9           4.3        1

# %%
df_val
# Out:
#      sepal_width  petal_length  species
# 78           2.9           4.5        1
# 136          3.4           5.6        2
# 98           2.5           3.0        1
# 110          3.2           5.1        2
# 74           2.9           4.3        1

# %%
df_test
# Out:
#      sepal_width  petal_length  species
# 131          3.8           6.4        2
# 101          2.7           5.1        2
# 146          2.5           5.0        2
# 79           2.6           3.5        1
# 93           2.3           3.3        1

# %%
x_test = df_val.iloc[:,0:2].values
y_test = df_val.iloc[:,-1].values

# %% [markdown]
# # Case 1 Bagging

# %%
# Data from tree 1
df_bag = df_train.sample(8,replace = True)

x = df_bag.iloc[:,0:2]
y  = df_bag.iloc[:,-1]
df_bag
# Out:
#      sepal_width  petal_length  species
# 108          2.5           5.8        2
# 140          3.1           5.6        2
# 135          3.0           6.1        2
# 99           2.8           4.1        1
# 124          3.3           5.7        2
# 92           2.6           4.0        1
# 124          3.3           5.7        2
# 66           3.0           4.5        1

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from mlxtend.plotting import plot_decision_regions
from sklearn.metrics import accuracy_score

# %%
dt_bag1 = DecisionTreeClassifier()

# %%
def evaluate(clf,x,y):
    clf.fit(x,y)
    plot_tree(clf)
    plt.show()
    plot_decision_regions(x.values,y.values,clf = clf,legend = 2)
    y_pred = clf.predict(x_test)
    print(accuracy_score(y_test,y_pred))

# %%
evaluate(dt_bag1,x,y)
# Out:
# 1.0

# %%
# Data for tree 2
dt_bag = df_train.sample(8,replace = True)

# Fetch x and y
x = dt_bag.iloc[:,0:2]
y = dt_bag.iloc[:,-1]

# print dt_bag
dt_bag
# Out:
#      sepal_width  petal_length  species
# 97           2.9           4.3        1
# 149          3.0           5.1        2
# 66           3.0           4.5        1
# 60           2.0           3.5        1
# 92           2.6           4.0        1
# 92           2.6           4.0        1
# 108          2.5           5.8        2
# 149          3.0           5.1        2

# %%
dt_bag2 = DecisionTreeClassifier()
evaluate(dt_bag2,x,y)
# Out:
# 1.0

# %%
# Data for tree 2
dt_bag = df_train.sample(8,replace = True)

# Fetch x and y
x = dt_bag.iloc[:,0:2]
y = dt_bag.iloc[:,-1]

# print dt_bag
dt_bag
# Out:
#      sepal_width  petal_length  species
# 97           2.9           4.3        1
# 92           2.6           4.0        1
# 66           3.0           4.5        1
# 108          2.5           5.8        2
# 60           2.0           3.5        1
# 124          3.3           5.7        2
# 60           2.0           3.5        1
# 97           2.9           4.3        1

# %%
dt_bag3 = DecisionTreeClassifier()
evaluate(dt_bag3,x,y)
# Out:
# 0.8

# %% [markdown]
# # predict

# %%
df_test
# Out:
#      sepal_width  petal_length  species
# 131          3.8           6.4        2
# 101          2.7           5.1        2
# 146          2.5           5.0        2
# 79           2.6           3.5        1
# 93           2.3           3.3        1

# %%
print('Predictor 1',dt_bag1.predict(np.array([3.2,4.7]).reshape(1,2)))
print('Predictor 2',dt_bag1.predict(np.array([3.2,4.7]).reshape(1,2)))
print('Predictor 3',dt_bag1.predict(np.array([3.2,4.7]).reshape(1,2)))
# Out:
# Predictor 1 [1]
# Predictor 2 [1]
# Predictor 3 [1]

# %% [markdown]
# # Pasting
# ## you do row sampling without replacement

# %%
df_train
# Out:
#      sepal_width  petal_length  species
# 60           2.0           3.5        1
# 92           2.6           4.0        1
# 149          3.0           5.1        2
# 140          3.1           5.6        2
# 124          3.3           5.7        2
# 135          3.0           6.1        2
# 66           3.0           4.5        1
# 108          2.5           5.8        2
# 99           2.8           4.1        1
# 97           2.9           4.3        1

# %%
df_train.sample(10)
# Out:
#      sepal_width  petal_length  species
# 124          3.3           5.7        2
# 66           3.0           4.5        1
# 97           2.9           4.3        1
# 140          3.1           5.6        2
# 149          3.0           5.1        2
# 108          2.5           5.8        2
# 135          3.0           6.1        2
# 99           2.8           4.1        1
# 92           2.6           4.0        1
# 60           2.0           3.5        1

# %% [markdown]
# # Random Subspaces
# ## do column sampling with or without replacement

# %%
df1 = sns.load_dataset('iris')

# %%
df1  = df1.sample(10)

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 61            5.9          3.0           4.2          1.5  versicolor
# 129           7.2          3.0           5.8          1.6   virginica
# 37            4.9          3.6           1.4          0.1      setosa
# 19            5.1          3.8           1.5          0.3      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 100           6.3          3.3           6.0          2.5   virginica
# 63            6.1          2.9           4.7          1.4  versicolor
# 94            5.6          2.7           4.2          1.3  versicolor
# 57            4.9          2.4           3.3          1.0  versicolor
# 3             4.6          3.1           1.5          0.2      setosa

# %%
df1.sample(2,replace = True,axis = 1)
# Out:
#      petal_length     species
# 61            4.2  versicolor
# 129           5.8   virginica
# 37            1.4      setosa
# 19            1.5      setosa
# 5             1.7      setosa
# 100           6.0   virginica
# 63            4.7  versicolor
# 94            4.2  versicolor
# 57            3.3  versicolor
# 3             1.5      setosa

# %% [markdown]
# # Random  Patches
# ## both row and column sampling

# %%
df1.sample(8,replace = True).sample(2,replace = True,axis = 1)
# Out:
#     sepal_length  petal_width
# 63           6.1          1.4
# 5            5.4          0.4
# 19           5.1          0.3
# 37           4.9          0.1
# 57           4.9          1.0
# 94           5.6          1.3
# 37           4.9          0.1
# 37           4.9          0.1
