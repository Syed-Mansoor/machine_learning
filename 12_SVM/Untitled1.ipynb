# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('airfoil_self_noise.dat',sep = '\t',header = None)

# %%
df.head(2)
# Out:
#       0    1       2     3         4        5
# 0   800  0.0  0.3048  71.3  0.002663  126.201
# 1  1000  0.0  0.3048  71.3  0.002663  125.201

# %%
df.columns = ['Frequancy','Angle_of_attack','Chord_length','Free_stream_velocity','Suction_side','Pressure_level']

# %%
df.head()
# Out:
#    Frequancy  Angle_of_attack  Chord_length  Free_stream_velocity  \
# 0        800              0.0        0.3048                  71.3
# 1       1000              0.0        0.3048                  71.3
# 2       1250              0.0        0.3048                  71.3
# 3       1600              0.0        0.3048                  71.3
# 4       2000              0.0        0.3048                  71.3
#
#    Suction_side  Pressure_level
# 0      0.002663         126.201
# 1      0.002663         125.201
# 2      0.002663         125.951
# 3      0.002663         127.591
# 4      0.002663         127.461

# %%
df.columns
# Out:
# Index(['Frequancy', 'Angle_of_attack', 'Chord_length', 'Free_stream_velocity',
#        'Suction_side', 'Pressure_level'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Frequancy               0
# Angle_of_attack         0
# Chord_length            0
# Free_stream_velocity    0
# Suction_side            0
# Pressure_level          0
# dtype: int64

# %%
x  = df.iloc[:,:-1]
y  = df.iloc[:,-1]

# %%
# train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.33,random_state = 42)

# %%
import seaborn as sns

# %%
sns.pairplot(x_train)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.corr()
# Out:
#                       Frequancy  Angle_of_attack  Chord_length  \
# Frequancy              1.000000        -0.272765     -0.003661
# Angle_of_attack       -0.272765         1.000000     -0.504868
# Chord_length          -0.003661        -0.504868      1.000000
# Free_stream_velocity   0.133664         0.058760      0.003787
# Suction_side          -0.230107         0.753394     -0.220842
# Pressure_level        -0.390711        -0.156108     -0.236162
#
#                       Free_stream_velocity  Suction_side  Pressure_level
# Frequancy                         0.133664     -0.230107       -0.390711
# Angle_of_attack                   0.058760      0.753394       -0.156108
# Chord_length                      0.003787     -0.220842       -0.236162
# Free_stream_velocity              1.000000     -0.003974        0.125103
# Suction_side                     -0.003974      1.000000       -0.312670
# Pressure_level                    0.125103     -0.312670        1.000000

# %%
x_train.corr()
# Out:
#                       Frequancy  Angle_of_attack  Chord_length  \
# Frequancy              1.000000        -0.273327     -0.000324
# Angle_of_attack       -0.273327         1.000000     -0.498257
# Chord_length          -0.000324        -0.498257      1.000000
# Free_stream_velocity   0.125247         0.058603      0.013061
# Suction_side          -0.239878         0.762567     -0.220849
#
#                       Free_stream_velocity  Suction_side
# Frequancy                         0.125247     -0.239878
# Angle_of_attack                   0.058603      0.762567
# Chord_length                      0.013061     -0.220849
# Free_stream_velocity              1.000000     -0.000519
# Suction_side                     -0.000519      1.000000

# %%
sns.heatmap(x_train.corr())
# Out:
# <Axes: >

# %%
for i in x_train.columns:
    sns.boxplot(x_train)

# %%
sns.boxplot(x_train['Frequancy'])
# Out:
# <Axes: >

# %%
sns.scatterplot(x = x_train['Frequancy'],y=y)
# Out:
# <Axes: xlabel='Frequancy', ylabel='Pressure_level'>

# %%
len(df['Pressure_level'].unique())
# Out:
# 1456

# %%
sns.boxenplot(df[])
